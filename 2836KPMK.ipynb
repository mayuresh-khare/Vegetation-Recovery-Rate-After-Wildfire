# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/vegetation_recovery_dataset_india.csv.xls")
df.head()
# Out:
#          date                    location  time_since_fire   ndvi  \
# 0  2023-08-14  Simlipal Biosphere Reserve             44.7  0.764
# 1  2021-09-20     Kaziranga National Park              4.9  0.566
# 2  2016-05-19     Kaziranga National Park             30.1  0.555
# 3  2019-01-08      Anamalai Tiger Reserve             58.2  0.754
# 4  2016-02-27                  Sundarbans             39.5  0.572
#
#    ndvi_pre_fire  ndvi_post_fire  temperature  rainfall  soil_moisture  \
# 0          0.756           0.634         33.7     350.6           0.31
# 1          0.651           0.462         21.5      58.1           0.46
# 2          0.816           0.519         16.5     245.4           0.20
# 3          0.575           0.234         11.2     471.4           0.44
# 4          0.683           0.318         14.6     476.1           0.37
#
#    burn_severity vegetation_type slope_and_elevation  vegetation_recovery_rate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      1000 non-null   object
#  1   location                  1000 non-null   object
#  2   time_since_fire           1000 non-null   float64
#  3   ndvi                      1000 non-null   float64
#  4   ndvi_pre_fire             1000 non-null   float64
#  5   ndvi_post_fire            1000 non-null   float64
#  6   temperature               1000 non-null   float64
#  7   rainfall                  1000 non-null   float64
#  8   soil_moisture             1000 non-null   float64
#  9   burn_severity             1000 non-null   int64
#  10  vegetation_type           1000 non-null   object
#  11  slope_and_elevation       1000 non-null   object
#  12  vegetation_recovery_rate  1000 non-null   float64
# dtypes: float64(8), int64(1), object(4)
# ...

# %%
df.isnull().sum()
# Out:
# date                        0
# location                    0
# time_since_fire             0
# ndvi                        0
# ndvi_pre_fire               0
# ndvi_post_fire              0
# temperature                 0
# rainfall                    0
# soil_moisture               0
# burn_severity               0
# vegetation_type             0
# slope_and_elevation         0
# vegetation_recovery_rate    0
# dtype: int64

# %%
df.drop(columns=["date"],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['location'] = label_encoder.fit_transform(df['location'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['vegetation_type'] = label_encoder.fit_transform(df['vegetation_type'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['slope_and_elevation'] = label_encoder.fit_transform(df['slope_and_elevation'])

# %%
df.head()
# Out:
#    location  time_since_fire   ndvi  ndvi_pre_fire  ndvi_post_fire  \
# 0         6             44.7  0.764          0.756           0.634
# 1         3              4.9  0.566          0.651           0.462
# 2         3             30.1  0.555          0.816           0.519
# 3         0             58.2  0.754          0.575           0.234
# 4         7             39.5  0.572          0.683           0.318
#
#    temperature  rainfall  soil_moisture  burn_severity  vegetation_type  \
# 0         33.7     350.6           0.31             17                2
# 1         21.5      58.1           0.46             26                2
# 2         16.5     245.4           0.20             47                3
# 3         11.2     471.4           0.44             95                1
# 4         14.6     476.1           0.37             46                2
#
#    slope_and_elevation  vegetation_recovery_rate
# 0                    2                    100.00
# ...

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns=["vegetation_recovery_rate"])
y = df["vegetation_recovery_rate"]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Absolute Error: 13.10154844457711
# Mean Squared Error: 256.085062940455
# R-squared Score: 0.8562285396398523

# %%
model.predict([[3, 44, 0.5, 0.6, 0.4, 30, 200, 0.40, 20, 2, 2]])
# Out:
# array([127.07553256])
